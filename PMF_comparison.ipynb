# %%
from plot_module import *

# %% [markdown]
# # TI results

# %%
method = "ti-block"

# %% [markdown]
# ## CB8-G1 - Meth

# %%
plot_comparison("results/GAFF2/APR_CB8G1-v2_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G1_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G2 - Fentanyl

# %%
plot_comparison("results/GAFF2/APR_CB8G2_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G2_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G3 - Morphine

# %%
plot_comparison("results/GAFF2/APR_CB8G3_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G3_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G4 - Hydromorphone

# %%
plot_comparison("results/GAFF2/APR_CB8G4_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G4_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G5 - Ketamine (+1)

# %%
plot_comparison("results/GAFF2/APR_CB8G5_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G5_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G5 - Ketamine (0)

# %%
plot_comparison("results/GAFF2/APR_CB8G5-0_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G5-0_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G6 - PCP

# %%
plot_comparison("results/GAFF2/APR_CB8G6_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G6_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G7 - Cocaine

# %%
plot_comparison("results/GAFF2/APR_CB8G7_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G7_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# # MBAR results

# %%
method = "mbar-autoc"

# %% [markdown]
# ## CB8-G1 - Meth

# %%
plot_comparison("results/GAFF2/APR_CB8G1-v2_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G1_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G2 - Fentanyl

# %%
plot_comparison("results/GAFF2/APR_CB8G2_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G2_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G3 - Morphine

# %%
plot_comparison("results/GAFF2/APR_CB8G3_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G3_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G4 - Hydromorphone

# %%
plot_comparison("results/GAFF2/APR_CB8G4_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G4_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G5 - Ketamine (+1)

# %%
plot_comparison("results/GAFF2/APR_CB8G5_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G5_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G5 - Ketamine (0)

# %%
plot_comparison("results/GAFF2/APR_CB8G5-0_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G5-0_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G6 - PCP

# %%
plot_comparison("results/GAFF2/APR_CB8G6_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G6_results.json", "Parsley v1.2.0", method=method)

# %% [markdown]
# ## CB8-G7 - Cocaine

# %%
plot_comparison("results/GAFF2/APR_CB8G7_results.json", "GAFF v2.11", "results/Parsley/APR_CB8G7_results.json", "Parsley v1.2.0", method=method)
